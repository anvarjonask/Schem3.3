# %%
import schemdraw
import schemdraw.elements as elm

# %%
with schemdraw.Drawing() as d:
    elm.Gap().up().label(['-', '$V_{gs}$', '+']).length(2).dot(open=True)
    elm.Line().right().length(1.5).label('G')
    elm.Capacitor().down().length(2).label(['$C_{gs}$'] , loc='bot')
    elm.Dot()
    d.push()
    elm.Line().left().length(1.5).dot(open=True)
    d.pop()
    elm.Line().right().length(1)
    elm.Line().right().length(2).label('S', loc='bot')
    elm.Dot()
    elm.Line().right().length(1.2)
    elm.Dot()
    d.push()
    elm.Line().right().length(0.6).dot(open=True)
    d.pop()
    elm.Resistor().up().length(2).label('$r_{o}$', loc='bot')
    elm.Dot()
    d.push()
    elm.Line().right().length(0.6).dot(open=True).label('D')
    d.pop()
    elm.Line().left().length(1.2)
    elm.SourceControlledI().down().length(2).label('$g_{m}V_{gs}$')
